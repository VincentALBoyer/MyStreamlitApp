# %% [markdown]
# # 🧩 Escape Room: Gestión de la Cadena de Suministro
# ### EGEL Plus IINDU - Área 2
#
# Este cuaderno te guiará por una serie de retos basados en tu formulario oficial. Deberás localizar fórmulas y variables específicas dentro de las páginas 24 a 30 del PDF.
#
# ---

# %%
# 1. Descargar utilidades (Simulado para local, el usuario en Colab lo descargará de GitHub)
import os
if not os.path.exists('game_utils.py'):
    # !wget https://raw.githubusercontent.com/VincentALBoyer/MyStreamlitApp/main/EGEL-Area2/game_utils.py

from game_utils import ColabGame

# 2. Iniciar el juego
game = ColabGame()
game.start()
