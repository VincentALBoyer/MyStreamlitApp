# %% [markdown]
# # 🏭 SAP SRM - Advanced Procurement Simulation
#
# **High-Robustness Streamlit Runner**
#
# This version uses specific security overrides to ensure it loads through Google's proxy system.
#
# ## 🎮 Instructions:
# 1. Run the **Installation** cell below.
# 2. Run the **Launch App** cell.
# 3. Wait for the '✨ READY' message—the app will appear below it.
#
# ---

# %%
# Step 1: Installation and File Setup
import os
import requests

def download_files():
    files = {
        "app.py": "https://raw.githubusercontent.com/VincentALBoyer/MyStreamlitApp/main/SRM_App/app.py",
        "logic.py": "https://raw.githubusercontent.com/VincentALBoyer/MyStreamlitApp/main/SRM_App/logic.py",
        "data.py": "https://raw.githubusercontent.com/VincentALBoyer/MyStreamlitApp/main/SRM_App/data.py"
    }
    
    print("📥 Downloading latest app files...")
    for filename, url in files.items():
        r = requests.get(url)
        with open(filename, 'wb') as f:
            f.write(r.content)
        print(f"  ✅ {filename} ready")

download_files()

print("📦 Installing Streamlit...")
# !pip install -q streamlit
print("✅ Environment Setup Complete!")

# %%
# Step 2: Launch App with Security Overrides
from google.colab import output
import subprocess
import time
import socket

PORT = 8501

def is_port_open(port):
    with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
        return s.connect_ex(('localhost', port)) == 0

# 1. Kill any existing instances
# !pkill streamlit
time.sleep(1)

print("🚀 Launching SRM Simulation...")

# 2. Start Streamlit with specific flags for Colab compatibility
cmd = [
    "streamlit", "run", "app.py",
    "--server.port", str(PORT),
    "--server.address", "localhost",
    "--server.headless", "true",
    "--server.enableCORS", "false",
    "--server.enableXsrfProtection", "false",
    "--browser.gatherUsageStats", "false"
]

process = subprocess.Popen(cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE)

# 3. Health check loop
print("⏳ Waiting for server to initialize...")
timeout = 30
start_time = time.time()
while not is_port_open(PORT):
    time.sleep(1)
    if time.time() - start_time > timeout:
        print("❌ Timeout waiting for Streamlit to start.")
        break

if is_port_open(PORT):
    print("✨ SERVER READY!")
    # 4. Display as iframe
    output.serve_kernel_port_as_iframe(PORT, width='100%', height='800')
else:
    print("Please try running this cell again.")
