# %% [markdown]
# # 🏭 SAP SRM - Advanced Procurement Simulation
#
# **Run the Full Streamlit App in Google Colab (Zero-Config)**
#
# This notebook runs the complete SRM Streamlit application directly in Google Colab using Localtunnel.
#
# ## 🎮 How to Use:
# 1. Run Step 1 & 2 to download files and install dependencies.
# 2. Run Step 3 to get your **Endpoint IP** (you will need this as a password).
# 3. Run Step 4 to start the app and click the **Localtunnel URL**.
# 4. When the page opens, paste your **Endpoint IP** into the box to start your session.
#
# ---

# %%
# Step 1: Download the SRM app files
print("📥 Downloading SRM app files...")
# !wget -q https://raw.githubusercontent.com/VincentALBoyer/MyStreamlitApp/main/SRM_App/app.py
# !wget -q https://raw.githubusercontent.com/VincentALBoyer/MyStreamlitApp/main/SRM_App/logic.py
# !wget -q https://raw.githubusercontent.com/VincentALBoyer/MyStreamlitApp/main/SRM_App/data.py
print("✅ Files downloaded!")

# %%
# Step 2: Install dependencies
print("📦 Installing Streamlit...")
# !pip install -q streamlit altair
print("✅ Installed!")

# %%
# Step 3: Get your Endpoint IP (Password for Localtunnel)
print("🔑 YOUR ENDPOINT IP IS:")
# !wget -qO- ipv4.icanhazip.com
print("\n👆 Copy this number! You will need to paste it when you click the link in the next step.")

# %%
# Step 4: Start Streamlit and Localtunnel
import subprocess
import time

print("🚀 Starting Streamlit app in background...")
# Run streamlit on port 8501
subprocess.Popen(["streamlit", "run", "app.py", "--server.port", "8501", "--server.address", "0.0.0.0"])

print("🌐 Opening tunnel...")
time.sleep(3)

# Use npx localtunnel to expose the port
# !npx localtunnel --port 8501

# %% [markdown]
# ---
# ## 💡 Troubleshooting
# **Localtunnel is asking for a password?**
# - This is for security. Paste the IP address from **Step 3** into the field and click 'Submit' or 'Click to Continue'.
#
# **The link isn't appearing?**
# - Sometimes it takes a few seconds. If it fails, stop the cell and run Step 4 again.
#
# **App crashed?**
# - Make sure you ran Step 1 to download the logic files!
